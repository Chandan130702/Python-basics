# %%
"""1. What is the difference between interpreted and compiled languages?
--> Interpreted: Code is executed line-by-line by an interpreter (like Python). It is generally easier to debug but slower to execute.
Compiled: The entire source code is converted into machine code by a compiler (like C++) before execution. This results in faster performance but longer development cycles.

2. What is exception handling in Python?
--> Exception handling is a mechanism to handle runtime errors gracefully using try, except, else, and finally blocks without crashing the program.

3. What is the purpose of the finally block in exception handling?
--> The finally block contains code that will always execute, regardless of whether an exception occurred or not. It's typically used for cleanup operations like closing files, releasing resources, or closing database connections.

4. What is logging in Python?
-->Logging is a means of tracking events that happen during program execution. It provides a way to record information about the program's behavior, errors, warnings, and other significant events to files or other output destinations.

5. What is the significance of the __del__ method in Python?
--> The __del__ method is a destructor that is called when an object is about to be destroyed or garbage collected. It's used to perform cleanup operations before the object is removed from memory.

6. What is the difference between import and from ... import in Python?
--> import module: Imports the entire module; you must use module.function() to access its contents.
from module import function: Imports specific attributes or functions directly into the current namespace, allowing you to use function() directly.

7. How can you handle multiple exceptions in Python?
--> You can handle multiple exceptions using multiple except blocks for different exception types, or by using a single except block with a tuple of exception types.

8. What is the purpose of the with statement when handling files in Python?
--> The with statement is used for resource management (context managers). It ensures that resources like files are automatically closed after the block of code is finished, even if an error occurs.

9. What is the difference between multithreading and multiprocessing?
--> Multithreading: Multiple threads run within the same memory space. Best for I/O-bound tasks.
Multiprocessing: Multiple processes run in separate memory spaces. Best for CPU-bound tasks as it bypasses the Global Interpreter Lock (GIL).

10. What are the advantages of using logging in a program?
--> Logging helps in debugging, tracking application flow, monitoring errors, and maintaining logs without interrupting program execution.

11. What is memory management in Python?
--> Memory management in Python involves the allocation and deallocation of memory for objects. Python automatically manages memory through its private heap space where all objects are stored.

12. What are the basic steps involved in exception handling in Python?
--> Basic steps in exception handling:
Try: Wrap the risky code.
Except: Catch and handle specific errors.
Else: Execute code if no errors occurred.
Finally: Execute cleanup code.

13. Why is memory management important in Python?
--> Memory management is crucial to prevent memory leaks, ensure efficient resource utilization, maintain application performance, and prevent out-of-memory errors. Poor memory management can lead to application crashes, reduced system performance, and wasted resources, especially in long-running applications.

14. What is the role of try and except in exception handling?
--> The try block contains code that might raise an exception. The except block catches and handles specific exceptions that occur in the try block.

15. How does Python's garbage collection system work?
--> Python primarily uses Reference Counting (deleting objects when their reference count hits zero) and a Generational Garbage Collector to find and fix reference cycles.

16. What is the purpose of the else block in exception handling?
--> The else block in a try-except statement executes only if the code in the try block does not raise an exception.

17. What are the common logging levels in Python?
--> The common logging levels in order of increasing severity are: DEBUG (detailed diagnostic information), INFO (general informational messages), WARNING (indication of potential problems), ERROR (serious problems that prevented a function from executing), and CRITICAL (very serious errors that may cause the program to terminate).

18. What is the difference between os.fork() and multiprocessing in Python?
--> os.fork(): A Unix-specific system call that creates a child process by copying the parent.
multiprocessing: A cross-platform Python module that provides a higher-level API for spawning processes.
19. What is the importance of closing a file in Python?
--> Closing a file frees up system resources and ensures that all buffered data is physically written to the disk.

20. What is the difference between file.read() and file.readline() in Python?
--> file.read() reads the entire file content as a single string (or specified number of bytes).
file.readline() reads a single line from the file including the newline character. read() is memory-intensive for large files, while readline() is more memory-efficient for processing files line by line.

21. What is the logging module in Python used for?
--> It provides a flexible framework for generating log messages from Python programs, allowing output to be directed to various destinations (console, files, etc.).

22. What is the os module in Python used for in file handling?
--> The os module provides functions for interacting with the operating system for file and directory operations. It includes functions to check file existence, create/delete directories, get file information, navigate the file system, manipulate file paths, and perform low-level file operations that are platform-independent.

23. What are the challenges associated with memory management in Python?
--> Challenges include managing memory for large data structures, dealing with circular references that can delay garbage collection, memory fragmentation in long-running applications, the overhead of reference counting, difficulty in predicting when objects will be deleted, and limited control over when garbage collection occurs.

24.  How do you raise an exception manually in Python?
--> You raise an exception manually using the raise keyword followed by an exception instance or exception class. For example: raise ValueError("Invalid input") or raise Exception(). You can raise built-in exceptions or create custom exceptions by inheriting from the Exception class.

25. Why is it important to use multithreading in certain applications?
--> It allows for concurrent execution, which is crucial for maintaining a responsive user interface or handling multiple network requests simultaneously without blocking the main program.
"""

# %%
#1. How can you open a file for writing in Python and write a string to it?
with open("example.txt", "w") as f:
    f.write("Hello, this is a test string.")

# %%
#2. Write a Python program to read the contents of a file and print each line.
with open("example.txt", "r") as f:
    for line in f:
        print(line.strip())
# Out:
# Hello, this is a test string.

# %%
#3. How would you handle a case where the file doesn't exist while trying to open it for reading?
try:
    with open("missing_file.txt", "r") as f:
        print(f.read())
except FileNotFoundError:
    print("Error: The file does not exist.")
# Out:
# Error: The file does not exist.

# %%
#4. Write a Python script that reads from one file and writes its content to another file.
try:
  with open("source.txt", "r") as src, open("destination.txt", "w") as dest:
    dest.write(src.read())
except:
  ("The file doesn't exist")

# %%
#5. How would you catch and handle division by zero error in Python?
try:
    result = 10 / 0
except ZeroDivisionError:
    print("Cannot divide by zero!")
# Out:
# Cannot divide by zero!

# %%
#6. Write a Python program that logs an error message to a log file when a division by zero exception occurs.
import logging
logging.basicConfig(filename="error.log", level=logging.ERROR)

try:
    x = 5 / 0
except ZeroDivisionError:
    logging.error("Division by zero occurred")
# Out:
# ERROR:root:Division by zero occurred

# %%
#7.How do you log information at different levels (INFO, ERROR, WARNING) in Python using the logging module?
import logging
logging.basicConfig(level=logging.INFO)

logging.info("Information message")
logging.warning("Warning message")
logging.error("Error message")
# Out:
# WARNING:root:Warning message
# ERROR:root:Error message

# %%
#8.Write a program to handle a file opening error using exception handling.
try:
    with open("file.txt", "r") as file:
        data = file.read()
except FileNotFoundError:
    print("Error: The file you are trying to open does not exist.")
except Exception as e:
    print(f"An unexpected error occurred: {e}")
# Out:
# Error: The file you are trying to open does not exist.

# %%
#9. How can you read a file line by line and store its content in a list in Python?
lines_list = []
try:
    with open("example.txt", "r") as file:
        for line in file:
            lines_list.append(line.strip())
    print(lines_list)
except FileNotFoundError:
    print("File not found.")
# Out:
# ['Hello, this is a test string.']

# %%
#10. How can you append data to an existing file in Python?
with open('output.txt', 'a') as file:
    file.write("\nThis is appended text.")
    file.write("\nAnother line of appended text.")
lines_to_append = [
    "\nFirst appended line",
    "\nSecond appended line",
    "\nThird appended line"
]
with open('output.txt', 'a') as file:
    file.writelines(lines_to_append)

# %%
# 11. Write a Python program that uses a try-except block to handle an error when attempting to access a dictionary key that doesn't exist.
student_info = {
    "name": "Alice",
    "course": "Data Science",
    "id": 101
}
try:
    grade = student_info["grade"]
    print(f"The student's grade is: {grade}")
except KeyError:
    print("Error: The key 'grade' does not exist in the dictionary.")
# Out:
# Error: The key 'grade' does not exist in the dictionary.

# %%
# 12.Write a program that demonstrates using multiple except blocks to handle different types of exceptions.
try:
    number = int(input("Enter a divisor: "))

    result = 100 / number
    print(f"100 divided by {number} is {result}")

    with open("config_data.txt", "r") as file:
        content = file.read()

except ValueError:
    print("Error: That wasn't a valid integer.")

except ZeroDivisionError:
    print("Error: You cannot divide by zero.")

except FileNotFoundError:
    print("Error: The file 'config_data.txt' was not found.")

except Exception as e:
    print(f"An unexpected error occurred: {e}")
# Out:
# Enter a divisor: 66
# 100 divided by 66 is 1.5151515151515151
# Error: The file 'config_data.txt' was not found.

# %%
#13. How would you check if a file exists before attempting to read it in Python?
def read_file_if_exists(filename):
    if os.path.exists(filename):
        print(f"File '{filename}' exists.")
        with open(filename, 'r') as file:
            content = file.read()
            print(content)
    else:
        print(f"File '{filename}' does not exist.")

# %%
#14. Write a program that uses the logging module to log both informational and error messages.
import logging
logging.basicConfig(
    level=logging.INFO,
    format='%(levelname)s: %(message)s'
)

def divide_numbers(a, b):
    logging.info(f"Attempting to divide {a} by {b}")
    try:
        result = a / b
        logging.info(f"Division successful. Result: {result}")
        return result
    except ZeroDivisionError:
        logging.error("Division by zero error occurred!")
        return None

divide_numbers(10, 2)
divide_numbers(10, 0)
# Out:
# ERROR:root:Division by zero error occurred!

# %%
#15. Write a Python program that prints the content of a file and handles the case when the file is empty.
try:
    with open("data.txt", "r") as file:
        content = file.read()
        if not content:
            print("The file is empty.") [cite: 49]
        else:
            print(content) [cite: 49]
except FileNotFoundError:
    print("File not found.")
# Out:
# File not found.

# %%
#16. Demonstrate how to use memory profiling to check the memory usage of a small program.
import tracemalloc
import sys


tracemalloc.start()


large_list = [i for i in range(100000)]
large_dict = {i: i**2 for i in range(10000)}


current, peak = tracemalloc.get_traced_memory()

print(f"Current memory usage: {current / 1024 / 1024:.2f} MB")
print(f"Peak memory usage: {peak / 1024 / 1024:.2f} MB")


tracemalloc.stop()

print(f"\nSize of list: {sys.getsizeof(large_list) / 1024:.2f} KB")
print(f"Size of dict: {sys.getsizeof(large_dict) / 1024:.2f} KB")
# Out:
# Current memory usage: 4.69 MB
# Peak memory usage: 4.71 MB
#
# Size of list: 782.21 KB
# Size of dict: 288.08 KB

# %%
# 17. Write a Python program to create and write a list of numbers to a file, one number per line.
numbers = [1, 2, 3, 4, 5, 10, 20, 30, 40, 50]

with open('numbers.txt', 'w') as file:
    for number in numbers:
        file.write(f"{number}\n")

print("Numbers written to file successfully!")

with open('numbers.txt', 'r') as file:
    print("\nFile content:")
    print(file.read())
# Out:
# Numbers written to file successfully!
#
# File content:
# 1
# 2
# 3
# 4
# 5
# 10
# 20
# 30
# 40
# 50

# %%
# 18. How would you implement a basic logging setup that logs to a file with rotation after 1MB?
import logging
from logging.handlers import RotatingFileHandler


log_file = "app_rotation.log"
max_bytes = 1 * 1024 * 1024
backup_count = 3


logger = logging.getLogger("MyRotatingLogger")
logger.setLevel(logging.INFO)


handler = RotatingFileHandler(log_file, maxBytes=max_bytes, backupCount=backup_count)

formatter = logging.Formatter('%(asctime)s - %(levelname)s - %(message)s')
handler.setFormatter(formatter)


logger.addHandler(handler)

logger.info("This is an informational message.")
logger.error("This is an error message that will be logged to a rotating file.")
# Out:
# INFO:MyRotatingLogger:This is an informational message.
# ERROR:MyRotatingLogger:This is an error message that will be logged to a rotating file.

# %%
#19. Write a program that handles both IndexError and KeyError using a try-except block.
try:
    my_list = [10, 20, 30, 40, 50]
    my_dict = {'name': 'John', 'age': 25, 'city': 'New York'}

    print(my_list[10])
    print(my_dict['salary'])

except IndexError:
    print("Error: List index out of range!")
except KeyError:
    print("Error: Dictionary key not found!")
# Out:
# Error: List index out of range!

# %%
#20. How would you open a file and read its contents using a context manager in Python?
try:
  with open("data.txt", "r") as file:
    content = file.read()
    print("File Contents:")
    print(content)

except FileNotFoundError:
  print("Error: The file you are trying to open does not exist.")
# Out:
# Error: The file you are trying to open does not exist.

# %%
#21. Write a Python program that reads a file and prints the number of occurrences of a specific word.
file_name = "example.txt"
target_word = "Python"

try:
    with open(file_name, "r") as file:
        content = file.read()


        words = content.split()
        occurrence_count = words.count(target_word)

        print(f"The word '{target_word}' appears {occurrence_count} times in the file.")

except FileNotFoundError:
    print(f"Error: The file '{file_name}' was not found.")
except Exception as e:
    print(f"An unexpected error occurred: {e}")
# Out:
# The word 'Python' appears 0 times in the file.

# %%
#22.How can you check if a file is empty before attempting to read its contents?
import os

filename = "sample.txt"

try:
    if os.path.exists(filename):
        if os.path.getsize(filename) == 0:
            print(f"The file '{filename}' is empty.")
        else:
            with open(filename, 'r') as file:
                content = file.read()
                print("File Content:")
                print(content)
    else:
        print(f"Error: File '{filename}' not found!")
except Exception as e:
    print(f"Error: {e}")
# Out:
# Error: File 'sample.txt' not found!

# %%
#23. Write a Python program that writes to a log file when an error occurs during file handling.
import logging

logging.basicConfig(
    filename='file_errors.log',
    level=logging.ERROR,
    format='%(asctime)s - %(levelname)s - %(message)s'
)

def process_file(filename):
    try:
        with open(filename, 'r') as file:
            data = file.read()
            print("File content read successfully.")
    except (FileNotFoundError, PermissionError, IOError) as e:
        logging.error(f"Error handling file '{filename}': {e}")
        print(f"An error occurred. Check 'file_errors.log' for details.")

process_file("non_existent_data.txt")
# Out:
# ERROR:root:Error handling file 'non_existent_data.txt': [Errno 2] No such file or directory: 'non_existent_data.txt'
# An error occurred. Check 'file_errors.log' for details.
